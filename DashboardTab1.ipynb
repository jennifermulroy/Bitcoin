# %%
from CryptoAnalyzer.CryptoAnalyzer import *
from sklearn import preprocessing
import numpy as np
import datetime
import plotly.express as px
import hvplot.pandas
import matplotlib.pyplot as plt
import hvplot.pandas
import plotly.express as px
from pathlib import Path
from panel.interact import interact
import panel as pn

# %%
start_sp = datetime.datetime(2010, 7, 16)
end_sp = datetime.datetime(2019, 10, 1)
prices = GetPrices.yahoo(start_sp, end_sp, ["SPY", "DX-Y.NYB", "AGG", "DJCI", "GLD"])

# %%
BTC_path = Path("BTC_trading_history.csv")
prices_BTC = pd.read_csv(BTC_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
prices_BTC.drop(columns=['High', 'Low', 'Open', 'Volume', 'Adj Close'], inplace=True)

# %%
prices_BTC.hvplot(title='BTC') + prices['SPY'].hvplot() + prices["DX-Y.NYB"].hvplot()
# Out:
# :Layout
#    .Curve.I                               :Curve   [Date]   (Close)
#    .Curve.SPY                             :Curve   [Date]   (SPY)
#    .Curve.DX_hyphen_minus_Y_full_stop_NYB :Curve   [Date]   (DX-Y.NYB)

# %%
def choose_timeframe(year):

    
    return prices_BTC.loc[prices_BTC.index.year==year,:].hvplot.line()

timeframe = prices_BTC.index.year.unique()

interact(choose_timeframe, year=timeframe)
# Out:
# Column
#     [0] Column
#         [0] DiscreteSlider(formatter='%d', name='year', options=[2010, 2011, 2012, ...], value=2010)
#     [1] Row
#         [0] HoloViews(Curve, name='interactive07940')

# %%
start_sp = datetime.datetime(2014, 10, 1)
end_sp = datetime.datetime(2019, 10, 1)
prices_five = GetPrices.yahoo(start_sp, end_sp, ["BTC-USD", "SPY", "DX-Y.NYB", "AGG", "DJCI", "GLD"])

# %%
BTC_max_price = prices_five.loc[prices_five['BTC-USD'] == prices_five['BTC-USD'].max()]
SPY_max_price = prices_five.loc[prices_five['SPY'] == prices_five['SPY'].max()] 

print('Bitcoin reached a record high on December 12, 2016 and the S&P500 reached its most recent record high on July 26, 2019')
print(BTC_max_price) 
print(SPY_max_price)
# Out:
# Bitcoin reached a record high on December 12, 2016 and the S&P500 reached its most recent record high on July 26, 2019
#                  BTC-USD  SPY  DX-Y.NYB  AGG  DJCI  GLD
# Date
# 2017-12-16  19497.400391  NaN       NaN  NaN   NaN  NaN
#                 BTC-USD        SPY   DX-Y.NYB         AGG   DJCI         GLD
# Date
# 2019-07-26  9477.677734  302.01001  98.010002  111.209999  14.65  133.639999
